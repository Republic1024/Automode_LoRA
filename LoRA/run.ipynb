# %%
#success
# !python "main.py" --project_name "Dreambooth_dog" --training_model "C:\\Users\\Administrator\\Downloads\\sd-v1-4.ckpt" --regularization_images "C:\\Users\\Administrator\\Desktop\\Dreambooth-Stable-Diffusion-main\\image\\regularization\\regularization_rabbit" --training_images "C:\\Users\\Administrator\\Desktop\\Dreambooth-Stable-Diffusion-main\\image\\samples\\rabbit" --max_training_steps 2000 --class_word "rabbit" --token "tiantian" --flip_p 0 --learning_rate 1.0e-06 --save_every_x_steps 500

# %%
# !python "main.py" --project_name "Dreambooth_rabbit" --training_model "C:\\Users\\Administrator\\Downloads\\sd-v1-4.ckpt" --regularization_images "C:\\Users\\Administrator\\Desktop\\Dreambooth-Stable-Diffusion-main\\image\\regularization\\regularization_rabbit" --training_images "C:\\Users\\Administrator\\Desktop\\Dreambooth-Stable-Diffusion-main\\image\\samples\\rabbit" --max_training_steps 2000 --class_word "rabbit" --token "tiantian" --flip_p 0 --learning_rate 1.0e-06 --save_every_x_steps 500

# %%
# niu niu 
# !python "main.py" --project_name "Dreambooth_rabbit" --training_model "C:\\Users\\Administrator\\Downloads\\sd-v1-4.ckpt" --regularization_images "C:\\Users\\Administrator\\Desktop\\Dreambooth-Stable-Diffusion-main\\image\\regularization\\regular_niuniu" --training_images "C:\\Users\\Administrator\\Desktop\\Dreambooth-Stable-Diffusion-main\\image\\samples\\niuniu" --max_training_steps 2000 --class_word "rabbit" --token "niuniu" --flip_p 0 --learning_rate 1.0e-06 --save_every_x_steps 1000
# Out:
# gpu_vram: 23.99 GB
# Loading model from C:\\Users\\Administrator\\Downloads\\sd-v1-4.ckpt
#
#
# ---------------------------
# <THIS IS LIKELY NOT AN ERROR>
# LatentDiffusion: Running in eps-prediction mode
# DiffusionWrapper has 859.52 M params.
# making attention of type 'vanilla' with 512 in_channels
# Working with z of shape (1, 4, 64, 64) = 16384 dimensions.
# making attention of type 'vanilla' with 512 in_channels
# Restored from C:\\Users\\Administrator\\Downloads\\sd-v1-4.ckpt with 0 missing and 3 unexpected keys
# Unexpected Keys: ['model_ema.decay', 'model_ema.num_updates', 'cond_stage_model.transformer.text_model.embeddings.position_ids']
# </THIS IS LIKELY NOT AN ERROR>
# ---------------------------
#
#
# LatentDiffusion: Also optimizing conditioner params!
# Project config
# model:
#   base_learning_rate: 1.0e-06
#   target: ldm.models.diffusion.ddpm.LatentDiffusion
#   params:
#     reg_weight: 1.0
#     linear_start: 0.00085
#     linear_end: 0.012
# ...

# %%
# !python "main.py" --project_name "Dreambooth_wuyao" --training_model "C:\\Users\\Administrator\\Downloads\\sd-v1-4.ckpt" --regularization_images "C:\\Users\\Administrator\\Desktop\\Dreambooth-Stable-Diffusion-main\\image\\regularization\\regular_me" --training_images "C:\\Users\\Administrator\\Desktop\\Dreambooth-Stable-Diffusion-main\\image\\samples\\me" --max_training_steps 2000 --class_word "man" --token "wuyao" --flip_p 0 --learning_rate 1.0e-06 --save_every_x_steps 1000

# %%
model_path = r"C:\Users\Administrator\Desktop\Dreambooth-Stable-Diffusion-main\trained_models\2024-01-24T04-08-55_Dreambooth_dog_02000_steps_9_training_images_tiantian_token_rabbit_class_word.ckpt"

# !python "main.py" --project_name "Dreambooth_niuniu_based_tiantian" --training_model "$model_path" --regularization_images "C:\\Users\\Administrator\\Desktop\\Dreambooth-Stable-Diffusion-main\\image\\regularization\\regular_niuniu" --training_images "C:\\Users\\Administrator\\Desktop\\Dreambooth-Stable-Diffusion-main\\image\\samples\\niuniu" --max_training_steps 2000 --class_word "rabbit" --token "niuniu" --flip_p 0 --learning_rate 1.0e-06 --save_every_x_steps 1000
# Out:
# gpu_vram: 23.99 GB
# Loading model from C:\Users\Administrator\Desktop\Dreambooth-Stable-Diffusion-main\trained_models\2024-01-24T04-08-55_Dreambooth_dog_02000_steps_9_training_images_tiantian_token_rabbit_class_word.ckpt
#
#
# ---------------------------
# <THIS IS LIKELY NOT AN ERROR>
# LatentDiffusion: Running in eps-prediction mode
# DiffusionWrapper has 859.52 M params.
# making attention of type 'vanilla' with 512 in_channels
# Working with z of shape (1, 4, 64, 64) = 16384 dimensions.
# making attention of type 'vanilla' with 512 in_channels
# Restored from C:\Users\Administrator\Desktop\Dreambooth-Stable-Diffusion-main\trained_models\2024-01-24T04-08-55_Dreambooth_dog_02000_steps_9_training_images_tiantian_token_rabbit_class_word.ckpt with 0 missing and 0 unexpected keys
# </THIS IS LIKELY NOT AN ERROR>
# ---------------------------
#
#
# LatentDiffusion: Also optimizing conditioner params!
# Project config
# model:
#   base_learning_rate: 1.0e-06
# ...

# %%
#infer
# !python scripts/stable_txt2img.py --ddim_eta 0.0 --n_samples 8 --n_iter 1 --scale 10.0 --ddim_steps 50  --ckpt "C:\\Users\\Administrator\\Desktop\\Dreambooth-Stable-Diffusion-main\\logs\\2024-01-24T03-27-51_Dreambooth_dog\\ckpts\\last.ckpt" --prompt "a tiantian rabbit and Mooncake"
# Out:
# Loading model from C:\\Users\\Administrator\\Desktop\\Dreambooth-Stable-Diffusion-main\\logs\\2024-01-24T03-27-51_Dreambooth_dog\\ckpts\\last.ckpt
# Global Step: 2000
# LatentDiffusion: Running in eps-prediction mode
# DiffusionWrapper has 859.52 M params.
# making attention of type 'vanilla' with 512 in_channels
# Working with z of shape (1, 4, 32, 32) = 4096 dimensions.
# making attention of type 'vanilla' with 512 in_channels
# Data shape for DDIM sampling is (8, 4, 64, 64), eta 0.0
# Running DDIM Sampling with 50 timesteps
# Your samples are ready and waiting for you here:
# outputs/txt2img-samples
#
# Enjoy.
# Global seed set to 42
#
# Sampling:   0%|          | 0/1 [00:00<?, ?it/s]
#
# data:   0%|          | 0/1 [00:00<?, ?it/s]
#
#
# DDIM Sampler:   0%|          | 0/50 [00:00<?, ?it/s]
#
#
# DDIM Sampler:   2%|▏         | 1/50 [00:01<01:09,  1.42s/it]
#
#
# DDIM Sampler:   4%|▍         | 2/50 [00:01<00:40,  1.19it/s]
#
#
# ...

# %%
model_path = r"C:\Users\Administrator\Desktop\Dreambooth-Stable-Diffusion-main\trained_models\2024-01-24T04-08-55_Dreambooth_dog_01000_steps_9_training_images_tiantian_token_rabbit_class_word.ckpt"
# model_path = r"C:\Users\Administrator\Desktop\Dreambooth-Stable-Diffusion-main\trained_models\2024-01-25T11-34-53_Dreambooth_niuniu_based_tiantian_02000_steps_7_training_images_niuniu_token_rabbit_class_word.ckpt"
prompt = "a tiantian rabbit and pikachu playing together in the beach, sunny day"

# infer
# !python scripts/stable_txt2img.py --ddim_eta 0.0 --n_samples 8 --n_iter 1 --scale 10.0 --ddim_steps 50 --ckpt "$model_path" --prompt "$prompt"
# Out:
# Loading model from C:\Users\Administrator\Desktop\Dreambooth-Stable-Diffusion-main\trained_models\2024-01-24T04-08-55_Dreambooth_dog_02000_steps_9_training_images_tiantian_token_rabbit_class_word.ckpt
# Global Step: 2000
# LatentDiffusion: Running in eps-prediction mode
# DiffusionWrapper has 859.52 M params.
# making attention of type 'vanilla' with 512 in_channels
# Working with z of shape (1, 4, 32, 32) = 4096 dimensions.
# making attention of type 'vanilla' with 512 in_channels
# Data shape for DDIM sampling is (8, 4, 64, 64), eta 0.0
# Running DDIM Sampling with 50 timesteps
# Your samples are ready and waiting for you here:
# outputs/txt2img-samples
#
# Enjoy.
# Global seed set to 42
#
# Sampling:   0%|          | 0/1 [00:00<?, ?it/s]
#
# data:   0%|          | 0/1 [00:00<?, ?it/s]
#
#
# DDIM Sampler:   0%|          | 0/50 [00:00<?, ?it/s]
#
#
# DDIM Sampler:   2%|▏         | 1/50 [00:01<01:17,  1.57s/it]
#
#
# DDIM Sampler:   4%|▍         | 2/50 [00:02<00:43,  1.11it/s]
#
#
# ...

# %%
niu_model = r"C:\Users\Administrator\Desktop\Dreambooth-Stable-Diffusion-main\trained_models\2024-01-25T11-34-53_Dreambooth_niuniu_based_tiantian_02000_steps_7_training_images_niuniu_token_rabbit_class_word.ckpt"
tian_model = r"C:\Users\Administrator\Desktop\Dreambooth-Stable-Diffusion-main\trained_models\2024-01-24T04-08-55_Dreambooth_dog_01000_steps_9_training_images_tiantian_token_rabbit_class_word.ckpt"

prompt_tail = "in Suzhou"
prompt_niu = "a niuniu rabbit "+prompt_tail
prompt_tian = "a tiantian rabbit "+prompt_tail

print(prompt_tian)

# infer
# !python scripts/stable_txt2img.py --ddim_eta 0.0 --n_samples 8 --n_iter 1 --scale 10.0 --ddim_steps 50 --ckpt "$niu_model" --prompt "$prompt_niu"
# !python scripts/stable_txt2img.py --ddim_eta 0.0 --n_samples 8 --n_iter 1 --scale 10.0 --ddim_steps 50 --ckpt "$tian_model" --prompt "$prompt_tian"
# Out:
# a tiantian rabbit in Suzhou
# Loading model from C:\Users\Administrator\Desktop\Dreambooth-Stable-Diffusion-main\trained_models\2024-01-25T11-34-53_Dreambooth_niuniu_based_tiantian_02000_steps_7_training_images_niuniu_token_rabbit_class_word.ckpt
# Global Step: 2000
# LatentDiffusion: Running in eps-prediction mode
# DiffusionWrapper has 859.52 M params.
# making attention of type 'vanilla' with 512 in_channels
# Working with z of shape (1, 4, 32, 32) = 4096 dimensions.
# making attention of type 'vanilla' with 512 in_channels
# Data shape for DDIM sampling is (8, 4, 64, 64), eta 0.0
# Running DDIM Sampling with 50 timesteps
# Your samples are ready and waiting for you here:
# outputs/txt2img-samples
#
# Enjoy.
# Global seed set to 42
#
# Sampling:   0%|          | 0/1 [00:00<?, ?it/s]
#
# data:   0%|          | 0/1 [00:00<?, ?it/s]
#
#
# DDIM Sampler:   0%|          | 0/50 [00:00<?, ?it/s]
#
#
# DDIM Sampler:   2%|▏         | 1/50 [00:01<01:01,  1.27s/it]
#
#
# ...

# %%
niu_model = r"C:\Users\Administrator\Desktop\Dreambooth-Stable-Diffusion-main\trained_models\2024-01-25T11-34-53_Dreambooth_niuniu_based_tiantian_02000_steps_7_training_images_niuniu_token_rabbit_class_word.ckpt"
tian_model = r"C:\Users\Administrator\Desktop\Dreambooth-Stable-Diffusion-main\trained_models\2024-01-24T04-08-55_Dreambooth_dog_01000_steps_9_training_images_tiantian_token_rabbit_class_word.ckpt"

prompt_tail = "in Shanghai"
prompt_niu = "a niuniu rabbit "+prompt_tail
prompt_tian = "a tiantian rabbit "+prompt_tail

print(prompt_tian)

# infer
# !python scripts/stable_txt2img.py --ddim_eta 0.0 --n_samples 8 --n_iter 1 --scale 10.0 --ddim_steps 50 --ckpt "$niu_model" --prompt "$prompt_niu"
# !python scripts/stable_txt2img.py --ddim_eta 0.0 --n_samples 8 --n_iter 1 --scale 10.0 --ddim_steps 50 --ckpt "$tian_model" --prompt "$prompt_tian"
# Out:
# a tiantian rabbit in Shanghai
# Loading model from C:\Users\Administrator\Desktop\Dreambooth-Stable-Diffusion-main\trained_models\2024-01-25T11-34-53_Dreambooth_niuniu_based_tiantian_02000_steps_7_training_images_niuniu_token_rabbit_class_word.ckpt
# Global Step: 2000
# LatentDiffusion: Running in eps-prediction mode
# DiffusionWrapper has 859.52 M params.
# making attention of type 'vanilla' with 512 in_channels
# Working with z of shape (1, 4, 32, 32) = 4096 dimensions.
# making attention of type 'vanilla' with 512 in_channels
# Data shape for DDIM sampling is (8, 4, 64, 64), eta 0.0
# Running DDIM Sampling with 50 timesteps
# Your samples are ready and waiting for you here:
# outputs/txt2img-samples
#
# Enjoy.
# Global seed set to 42
#
# Sampling:   0%|          | 0/1 [00:00<?, ?it/s]
#
# data:   0%|          | 0/1 [00:00<?, ?it/s]
#
#
# DDIM Sampler:   0%|          | 0/50 [00:00<?, ?it/s]
#
#
# DDIM Sampler:   2%|▏         | 1/50 [00:01<01:01,  1.25s/it]
#
#
# ...

# %%
#infer me
# !python scripts/stable_txt2img.py --ddim_eta 0.0 --n_samples 8 --n_iter 1 --scale 10.0 --ddim_steps 50  --ckpt "C:\\Users\\Administrator\\Desktop\\Dreambooth-Stable-Diffusion-main\\trained_models\\2024-01-24T08-26-58_Dreambooth_wuyao_02000_steps_5_training_images_wuyao_token_man_class_word.ckpt" --prompt "a man wuyao in Tianan square, Beijing"
# Out:
# Loading model from C:\\Users\\Administrator\\Desktop\\Dreambooth-Stable-Diffusion-main\\trained_models\\2024-01-24T08-26-58_Dreambooth_wuyao_02000_steps_5_training_images_wuyao_token_man_class_word.ckpt
# Global Step: 2000
# LatentDiffusion: Running in eps-prediction mode
# DiffusionWrapper has 859.52 M params.
# making attention of type 'vanilla' with 512 in_channels
# Working with z of shape (1, 4, 32, 32) = 4096 dimensions.
# making attention of type 'vanilla' with 512 in_channels
# Data shape for DDIM sampling is (8, 4, 64, 64), eta 0.0
# Running DDIM Sampling with 50 timesteps
# Your samples are ready and waiting for you here:
# outputs/txt2img-samples
#
# Enjoy.
# Global seed set to 42
#
# Sampling:   0%|          | 0/1 [00:00<?, ?it/s]
#
# data:   0%|          | 0/1 [00:00<?, ?it/s]
#
#
# DDIM Sampler:   0%|          | 0/50 [00:00<?, ?it/s]
#
#
# DDIM Sampler:   2%|▏         | 1/50 [00:01<01:34,  1.93s/it]
#
#
# DDIM Sampler:   4%|▍         | 2/50 [00:02<00:50,  1.05s/it]
#
#
# ...

# %%
# !code C:\Users\Administrator\mambaforge\envs\ladivton\lib\site-packages\taming\modules\vqvae\quantize.py
